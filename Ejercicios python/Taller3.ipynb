# %% [markdown]
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.

# %%
def valiedad(eda):
  if eda > 55:
    print("Aplica para bono de prepension")
  else:
    print("No aplica para bono de prepension")

resp = "si"
while resp == "si" or resp == "s":
  numeiden=1023916989
  nombres="cristian mora"
  apellidos="mora marin"
  Direccion="calle 130 #103-56" 
  teléfono=3057721640
  edad= int(input("digite su edad"))
  valiedad(edad)
  Est_Civi="union libre"
  num_hijos=2
  Est_cm= "162 cm"
  fch_contra="02/07/2022"
  Suel_basi="1.000.000"
  dia_labo=250
  resp = input("¿Desea realizar otra comparación?")
# Out:
# digite su edad30
# No aplica para bono de prepension
# ¿Desea realizar otra comparación?si
# digite su edad57
# Aplica para bono de prepension
# ¿Desea realizar otra comparación?n

# %% [markdown]
# 2. Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre

# %%
def valesta(valest):
  if Est_Civi in "casado" and num_hijos > 0:
    print("Aplica para paseo de diciembre")
  else:
   print("No aplica para paseo de diciembre")

resp = "si"
while resp == "si" or resp == "s:":
  numeiden=1023916989
  nombres="cristian mora"
  apellidos="mora marin"
  Direccion="calle 130 #103-56" 
  teléfono=3057721640
  Est_Civi="union libre"
  valesta(Est_Civi)
  num_hijos=2
  Est_cm= "162 cm"
  fch_contra="02/07/2022"
  Suel_basi="1.000.000"
  dia_labo=250
  resp = input("¿Desea realizar otra comparación?")
# Out:
# No aplica para paseo de diciembre
# ¿Desea realizar otra comparación?mo
