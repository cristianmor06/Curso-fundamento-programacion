# %% [markdown]
# Taller 2:
#
# Dando continuidad con la primera entrega del proyecto, en esta oportunidad el estudiante debe realizar las siguientes validaciones utilizando la sentencia condicional IF.
#
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
#
# Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
#
# Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.
#
# Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %% [markdown]
# 1. Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.

# %%
numeiden=1023916989
nombres="cristian mora"
apellidos="mora marin"
Direccion="calle 130 #103-56" 
teléfono=3057721640
edad=30
Est_Civi="union libre"
num_hijos=2
Est_cm= "162 cm"
fch_contra="02/07/2022"
Suel_basi="1.000.000"
dia_labo=250
if edad <= 55:
  print("No aplica para bono prepension")
# Out:
# No aplica para bono prepension

# %% [markdown]
# 2. Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre

# %%
numeiden=1023916989
nombres="cristian mora"
apellidos="mora marin"
Direccion="calle 130 #103-56" 
teléfono=3057721640
edad=30
Est_Civi="union libre"
num_hijos=2
Est_cm= "162 cm"
fch_contra="02/07/2022"
Suel_basi="1.000.000"
dia_labo=250
if Est_Civi in "casado" and num_hijos > 0:
  print("Aplica para paseo de diciembre")
else:
  print("No aplica para paseo de diciembre")
if edad <= 55:
  print("No aplica para bono prepension")
if Suel_basi >= "1.000.000":
  print("Aplica para comision del 2%")
if dia_labo > 20 and Suel_basi < "1.000.000":
  print("Aplica para bono de alimentacion")
else:
  print("No aplica para bono de alimentacion")
# Out:
# No aplica para paseo de diciembre
# No aplica para bono prepension
# Aplica para comision del 2%
# No aplica para bono de alimentacion

# %% [markdown]
# 3. Si el sueldo básico está entre 1000000 y 1500000 tendrá una comisión del 2% sobre el valor del sueldo; Si el sueldo básico está entre 1500001 y 2000000 tendrá una comisión del 5% sobre el valor del sueldo; para todos los demás casos no habrá comisión.

# %%
numeiden=1023916989
nombres="cristian mora"
apellidos="mora marin"
Direccion="calle 130 #103-56" 
teléfono=3057721640
edad=30
Est_Civi="union libre"
num_hijos=2
Est_cm= "162 cm"
fch_contra="02/07/2022"
Suel_basi="1.000.000"
dia_labo=250
if Suel_basi >= "1.000.000":
  print("Aplica para comision del 2%")
# Out:
# Aplica para comision del 2%

# %% [markdown]
# 4. Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %%
numeiden=1023916989
nombres="cristian mora"
apellidos="mora marin"
Direccion="calle 130 #103-56" 
teléfono=3057721640
edad=30
Est_Civi="union libre"
num_hijos=2
Est_cm= "162 cm"
fch_contra="02/07/2022"
Suel_basi="1.000.000"
dia_labo=250
if dia_labo > 20 and Suel_basi < "1.000.000":
  print("Aplica para bono de alimentacion")
else:
  print("No aplica para bono de alimentacion")
# Out:
# No aplica para bono de alimentacion
